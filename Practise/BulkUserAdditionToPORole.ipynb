# %%
import pandas as pd

# %%
data = pd.read_excel("cibg.xlsx")

# %%
data
# Out:
#          display_name                    mail  cost_center  \
# 0       Ankit Agrawal    aagrawal3@vmware.com        72013
# 1          Aakash Das      aakashd@vmware.com        72011
# 2        Ashok Akbote      aakbote@vmware.com        78938
# 3        Anuj Batwara     abatwara@vmware.com        79752
# 4     Asaf Blubshtein  ablubshtein@vmware.com        39427
# ..                ...                     ...          ...
# 444       Nikhil Nair      nikhiln@vmware.com        79201
# 445         Sarah Qiu    xiaohongq@vmware.com        79201
# 446          Joe Chen      joechen@vmware.com        79201
# 447      Devyani Shah       shahde@vmware.com        79201
# 448  Roshan Rodrigues   rodriguesr@vmware.com        79201
#
#                     extensionAttribute12  \
# 0    Cloud Infrastructure Business Group
# 1    Cloud Infrastructure Business Group
# 2    Cloud Infrastructure Business Group
# 3    Cloud Infrastructure Business Group
# 4    Cloud Infrastructure Business Group
# ...

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
polist = data[(data['DCR_new']==1)  & (data['Approve']=='Yes') & (data['Platform Admin']!='Yes')]

# %%
type(polist)
# Out:
# pandas.core.frame.DataFrame

# %%
polist
# Out:
#                   display_name                     mail  cost_center  \
# 2                 Ashok Akbote       aakbote@vmware.com        78938
# 3                 Anuj Batwara      abatwara@vmware.com        79752
# 8            Afham Ul Saad T A  afhamulsaadt@vmware.com        79752
# 23                  Abid Saeed        asaeed@vmware.com        79201
# 25               Andrew Sharpe       asharpe@vmware.com        79752
# 26     Sharukh Ainan Hajiameen      asharukh@vmware.com        79752
# 29                 Ahmad Tawil        atawil@vmware.com        79752
# 30                   Avakash D      avakashd@vmware.com        79752
# 32           Basavaraj Ainapur      bainapur@vmware.com        79752
# 43                   Bill Leff         bleff@vmware.com        79752
# 47                 Shrilaxmi B    bshrilaxmi@vmware.com        79752
# 70                 Daniel Hall       danhall@vmware.com        69600
# 74             Daniel Draganov     ddraganov@vmware.com        72013
# ...

# %%
mail = polist['mail']
mail
# Out:
# 2           aakbote@vmware.com
# 3          abatwara@vmware.com
# 8      afhamulsaadt@vmware.com
# 23           asaeed@vmware.com
# 25          asharpe@vmware.com
# 26         asharukh@vmware.com
# 29           atawil@vmware.com
# 30         avakashd@vmware.com
# 32         bainapur@vmware.com
# 43            bleff@vmware.com
# 47       bshrilaxmi@vmware.com
# 70          danhall@vmware.com
# 74        ddraganov@vmware.com
# 78         dhindsag@vmware.com
# 82     dmukhopadhya@vmware.com
# 105           goels@vmware.com
# 107         gsaloni@vmware.com
# 122        hsajjala@vmware.com
# 135        ivivaylo@vmware.com
# 149        jianfeix@vmware.com
# 165           jtian@vmware.com
# 181         kkojima@vmware.com
# 209        ljeffrey@vmware.com
# 217       lxiaochun@vmware.com
# 219    manasamithra@vmware.com
# 221            mann@vmware.com
# 232       mhiremath@vmware.com
# 236           miyal@vmware.com
# 249         nagraja@vmware.com
# 266         pcronis@vmware.com
# ...

# %%
 access_token = "eyJhbGciOiJSUzI1NiJ9..ZFt4x4WEsnoSLENKG_vDjWLf9HU_AnWq_z93yACCOkh48OjywlEQZUs9zfTvHq5KIf14K8PAzHTNZIbe-UdG6QgSO76fZPQ1Oys1ZkHqiUK5pLXpOaKY7dA5kOuwOLJFpxCo4xXgmT746nLvK_lxi5PN4J6PohwpsveNaeayX6uMgSDC-reMd8uvBnl60oL7OOAaUpEnmMAUfD0GoSomdMqZCSqsn_-djvVFc7XOEFnYfYtr2jD_DOwRPBTa-0MRNQuWev7QO80ynamsOAo_MNKjeLcpYcqly1CN0WLQh80ttgbLlRb3v5yYleS71ON8zPzKt6e0fFmQ4OXdyQTyKg"

# %%
import requests
#Porgram owner role in stage= 13736
url = "https://authorization.esp-staging.vmware-aws.com/api/authorize/v1/users/{0}/roles/13736?client_id=dxpress"
for index, row in polist.iterrows():
    mail = row["mail"]
    print(mail)
    newurl = url.format(mail)
    print("calling url "+ newurl)
    headers_string = {"content-type": "application/json; charset=UTF-8",'Authorization':'{}'.format(access_token)}
    print(headers_string)
    result = requests.post(newurl,headers=headers_string)
    print(result)
# Out:
# aakbote@vmware.com
# calling url https://authorization.esp-staging.vmware-aws.com/api/authorize/v1/users/aakbote@vmware.com/roles/13736?client_id=dxpress
# {'content-type': 'application/json; charset=UTF-8', 'Authorization': 'eyJhbGciOiJSUzI1NiJ9..ZFt4x4WEsnoSLENKG_vDjWLf9HU_AnWq_z93yACCOkh48OjywlEQZUs9zfTvHq5KIf14K8PAzHTNZIbe-UdG6QgSO76fZPQ1Oys1ZkHqiUK5pLXpOaKY7dA5kOuwOLJFpxCo4xXgmT746nLvK_lxi5PN4J6PohwpsveNaeayX6uMgSDC-reMd8uvBnl60oL7OOAaUpEnmMAUfD0GoSomdMqZCSqsn_-djvVFc7XOEFnYfYtr2jD_DOwRPBTa-0MRNQuWev7QO80ynamsOAo_MNKjeLcpYcqly1CN0WLQh80ttgbLlRb3v5yYleS71ON8zPzKt6e0fFmQ4OXdyQTyKg'}
# <Response [400]>
# ...
